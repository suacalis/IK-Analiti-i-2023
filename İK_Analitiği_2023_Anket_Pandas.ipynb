# %% [markdown]
# <a href="https://colab.research.google.com/github/suacalis/IK-Analitigi-2023/blob/main/%C4%B0K_Analiti%C4%9Fi_2023_Anket_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/Dersler/2022-2023 Bahar Dönemi/İK Analitiği/ikanalitikanket.xlsx')

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/suacalis/IK-Analitigi-2023/main/ikanalitikanket.csv', sep=';')

# %%
df2.head()
# Out:
#    Numaranız Cinsiyet  Doğum_Yılınız    Boy  Kilo Ayakkabı_Numara  \
# 0        1.0    Erkek         2001.0  176.0  62.0              39
# 1        2.0    Erkek         1988.0  175.0  70.0              43
# 2        3.0    Kadın         2002.0  167.0  50.0              39
# 3        4.0    Kadın         2002.0  158.0  47.0              37
# 4        5.0    Kadın         2001.0  157.0  38.0              36
#
#            Göz         Saç          Doğum_Köy Doğum_İlçe  ...  \
# 0  Kahverengi       Kumral             Pendik     Pendik  ...
# 1   Kahverengi       Siyah  Arifbey Mahallesi  Adapazarı  ...
# 2  Kahverengi   Kahverengi            İnegöl     İnegöl   ...
# 3   Kahverengi  Kahverengi          Şirinköyü    Gölcük   ...
# 4       Yeşil        Siyah             Hendek     Hendek  ...
#
#        Lise_ İlçe_İl Üniversite_Puan Sıralama  \
# 0   Çayırova/Kocaeli             295        1
# 1   Arifiye/Sakarya              NaN      NaN
# 2       İnegöl/Bursa             273        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Numaranız        77 non-null     int64
#  1   Cinsiyet         77 non-null     object
#  2   Doğum_Yılınız    77 non-null     int64
#  3   Boy              77 non-null     int64
#  4   Kilo             77 non-null     int64
#  5   Ayakkabı_Numara  77 non-null     float64
#  6   Göz              77 non-null     object
#  7   Saç              77 non-null     object
#  8   Doğum_Köy        74 non-null     object
#  9   Doğum_İlçe       77 non-null     object
#  10  Doğum_İl         77 non-null     object
#  11  Lise             77 non-null     object
#  12  Lise_ İlçe_İl    77 non-null     object
#  13  Üniversite_Puan  57 non-null     float64
#  14  Sıralama         59 non-null     object
#  15  İl               77 non-null     object
#  16  Baba_Eğitim      76 non-null     object
# ...

# %%
#Verileri ilk beş satırı göstererek inceleme
df.head()
# Out:
#    Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara          Göz  \
# 0          1    Erkek           2001  176    62             39.0  Kahverengi
# 1          2    Erkek           1988  175    70             43.0   Kahverengi
# 2          3    Kadın           2002  167    50             39.0  Kahverengi
# 3          4    Kadın           2002  158    47             37.0   Kahverengi
# 4          5    Kadın           2001  157    38             36.0       Yeşil
#
#           Saç          Doğum_Köy Doğum_İlçe  ...      Lise_ İlçe_İl  \
# 0      Kumral             Pendik     Pendik  ...   Çayırova/Kocaeli
# 1       Siyah  Arifbey Mahallesi  Adapazarı  ...   Arifiye/Sakarya
# 2  Kahverengi            İnegöl     İnegöl   ...       İnegöl/Bursa
# 3  Kahverengi          Şirinköyü    Gölcük   ...     Hendek/Sakarya
# 4       Siyah             Hendek     Hendek  ...  Adapazarı/Sakarya
#
#   Üniversite_Puan Sıralama                                      İl  \
# ...

# %%
#Verileri son beş satırı göstererek inceleme
df.tail()
# Out:
#     Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara  \
# 72         73    Kadın           2001  163    43             37.0
# 73         74    Kadın           2000  165    48             36.0
# 74         75    Erkek           2001  185    70             42.0
# 75         76    Kadın           2001  157    48             38.0
# 76         77    Erkek           2000  178    80             44.0
#
#             Göz         Saç               Doğum_Köy   Doğum_İlçe  ...  \
# 72  Kahverengi   Kahverengi      Tepekkum Mahallesi    Adapazarı  ...
# 73  Kahverengi        Siyah  Süleymaniye Mahallesi       İnegöl   ...
# 74  Kahverengi        Siyah               Adapazarı    Adapazarı  ...
# 75  Kahverengi         Sarı                İstanbul  Sultanbeyli  ...
# 76  Kahverengi        Siyah         Tuzla Gözü Köyü      Kozluk   ...
#
#         Lise_ İlçe_İl Üniversite_Puan Sıralama  \
# 72    Erenler/Sakarya       273.10424       47
# 73       İnegöl/Bursa       253.00000      NaN
# ...

# %%
# Verilerin boyutlarını kontrol etme
df.shape
# Out:
# (77, 22)

# %%
#Her sütundaki benzersiz değerleri sayma
df.nunique()
# Out:
# Numaranız          77
# Cinsiyet            2
# Doğum_Yılınız       6
# Boy                25
# Kilo               27
# Ayakkabı_Numara    12
# Göz                 9
# Saç                 9
# Doğum_Köy          62
# Doğum_İlçe         42
# Doğum_İl           17
# Lise               73
# Lise_ İlçe_İl      49
# Üniversite_Puan    46
# Sıralama           51
# İl                 71
# Baba_Eğitim         5
# Baba_Meslek        32
# Anne_Eğitim         5
# Anne_Meslek        19
# Kardeş              7
# Not_Ortalama       62
# dtype: int64

# %%
#Her sütunun veri türünü kontrol etme
df.dtypes
# Out:
# Numaranız            int64
# Cinsiyet            object
# Doğum_Yılınız        int64
# Boy                  int64
# Kilo                 int64
# Ayakkabı_Numara    float64
# Göz                 object
# Saç                 object
# Doğum_Köy           object
# Doğum_İlçe          object
# Doğum_İl            object
# Lise                object
# Lise_ İlçe_İl       object
# Üniversite_Puan    float64
# Sıralama            object
# İl                  object
# Baba_Eğitim         object
# Baba_Meslek         object
# Anne_Eğitim         object
# Anne_Meslek         object
# Kardeş               int64
# Not_Ortalama       float64
# dtype: object

# %%
#İstediğimiz sütunları seçme
df[['Cinsiyet', 'Lise']]
# Out:
#    Cinsiyet                                               Lise
# 0     Erkek              Güzeltepe Fevzi Çakmak Anadolu Lisesi
# 1     Erkek                       Arifiye Çok Programlı Lisesi
# 2     Kadın              Nuh Mehmet Küçükçalık Anadolu Lisesi
# 3     Kadın         Osmangazi Mesleki ve Teknik Anadolu Lisesi
# 4     Kadın                Hacı Zehra Akkoç Kız Anadolu Lisesi
# ..      ...                                                ...
# 72    Kadın            Vali Mustafa Cahit Kıraç Anadolu Lisesi
# 73    Kadın  Toki Necip Fazıl Kısakürek Anadolu İmam Hatip ...
# 74    Erkek                                Sakarya Spor Lisesi
# 75    Kadın                       Çekmeköy Toki Anadolu Lisesi
# 76    Erkek                    Çorlu Anadolu İmam Hatip Lisesi
#
# [77 rows x 2 columns]

# %%
#Sütunlardaki eksik değerleri kontrol etme
df.isnull().sum()
# Out:
# Numaranız           0
# Cinsiyet            0
# Doğum_Yılınız       0
# Boy                 0
# Kilo                0
# Ayakkabı_Numara     0
# Göz                 0
# Saç                 0
# Doğum_Köy           3
# Doğum_İlçe          0
# Doğum_İl            0
# Lise                0
# Lise_ İlçe_İl       0
# Üniversite_Puan    20
# Sıralama           18
# İl                  0
# Baba_Eğitim         1
# Baba_Meslek         2
# Anne_Eğitim         1
# Anne_Meslek         0
# Kardeş              0
# Not_Ortalama        0
# dtype: int64

# %%
#Sütundaki değerleri toplama
df['Kilo'].sum()
# Out:
# 4410

# %%
df['Boy'].sum()
# Out:
# 12681

# %%
#Sütundaki değerlerin ortalama değerini alma
df['Kilo'].mean()
# Out:
# 57.27272727272727

# %%
df['Boy'].mean()
# Out:
# 164.6883116883117

# %%
df['Not_Ortalama'].mean()
# Out:
# 2.5779220779220777

# %%
df['Kardeş'].mean()
# Out:
# 2.0779220779220777

# %%
#Sütundaki değerlerin standart sapmasını alma
df['Boy'].std()
# Out:
# 7.557254688568323

# %%
df['Not_Ortalama'].std()
# Out:
# 0.4257357027371549

# %%
#Sütundaki değerlerin varyansını alma
df['Not_Ortalama'].var()
# Out:
# 0.1812508885850991

# %%
#Sütundaki en büyük değeri bulma
df['Not_Ortalama'].max()
# Out:
# 3.49

# %%
#Sütundaki en küçük değeri bulma
df['Not_Ortalama'].min()
# Out:
# 1.68

# %%
#Sütundaki değerlerin medyanını alma
df['Not_Ortalama'].median()
# Out:
# 2.55

# %%
#Sütundaki değerlerin modunu alma
df['Not_Ortalama'].mode()
# Out:
# 0    2.4
# Name: Not_Ortalama, dtype: float64

# %%
#Sütundaki değerlerin bir özeti
df['Not_Ortalama'].describe()
# Out:
# count    77.000000
# mean      2.577922
# std       0.425736
# min       1.680000
# 25%       2.310000
# 50%       2.550000
# 75%       2.840000
# max       3.490000
# Name: Not_Ortalama, dtype: float64

# %%
df.describe()
# Out:
#        Numaranız  Doğum_Yılınız         Boy       Kilo  Ayakkabı_Numara  \
# count  77.000000      77.000000   77.000000  77.000000        77.000000
# mean   39.000000    2000.792208  164.688312  57.272727        38.116883
# std    22.371857       1.734614    7.557255  10.724586         1.881167
# min     1.000000    1988.000000  150.000000  38.000000        34.000000
# 25%    20.000000    2000.000000  160.000000  50.000000        37.000000
# 50%    39.000000    2001.000000  163.000000  55.000000        38.000000
# 75%    58.000000    2002.000000  168.000000  62.000000        39.000000
# max    77.000000    2002.000000  185.000000  90.000000        44.000000
#
#        Üniversite_Puan     Kardeş  Not_Ortalama
# count        57.000000  77.000000     77.000000
# mean        285.727789   2.077922      2.577922
# std          32.803252   1.232949      0.425736
# min         225.000000   0.000000      1.680000
# 25%         268.110270   1.000000      2.310000
# ...

# %%
#Belirli bir değere eşit olan satırları seçme
df.loc[df['Not_Ortalama'] == 2]
# Out:
#    Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara         Göz  \
# 3          4    Kadın           2002  158    47             37.0  Kahverengi
#
#           Saç  Doğum_Köy Doğum_İlçe  ...   Lise_ İlçe_İl Üniversite_Puan  \
# 3  Kahverengi  Şirinköyü    Gölcük   ...  Hendek/Sakarya       272.02835
#
#   Sıralama                                 İl Baba_Eğitim Baba_Meslek  \
# 3        4  Sarıdede Mahallesi/Hendek/Sakarya    Ortaokul        İşçi
#
#   Anne_Eğitim Anne_Meslek Kardeş Not_Ortalama
# 3    Ortaokul        İşçi      2          2.0
#
# [1 rows x 22 columns]

# %%
#Belirli bir değerden büyük olan satırları seçme
df.loc[df['Not_Ortalama'] > 2]
# Out:
#     Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara  \
# 0           1    Erkek           2001  176    62             39.0
# 1           2    Erkek           1988  175    70             43.0
# 2           3    Kadın           2002  167    50             39.0
# 4           5    Kadın           2001  157    38             36.0
# 5           6    Kadın           2002  163    50             38.0
# ..        ...      ...            ...  ...   ...              ...
# 71         72    Kadın           2002  162    60             37.5
# 72         73    Kadın           2001  163    43             37.0
# 73         74    Kadın           2000  165    48             36.0
# 75         76    Kadın           2001  157    48             38.0
# 76         77    Erkek           2000  178    80             44.0
#
#             Göz         Saç               Doğum_Köy   Doğum_İlçe  ...  \
# 0   Kahverengi       Kumral                  Pendik       Pendik  ...
# ...

# %%
#Belirli bir değer aralığında olan satırları seçme
df.loc[(df['Not_Ortalama'] >= 1.68) & (df['Not_Ortalama'] <= 2)]
# Out:
#     Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara  \
# 3           4    Kadın           2002  158    47             37.0
# 6           7    Kadın           2001  160    50             36.0
# 10         11    Kadın           2002  165    50             38.0
# 23         24    Kadın           2001  158    48             39.0
# 38         39    Kadın           2001  160    50             36.0
# 54         55    Erkek           1999  180    80             43.0
# 68         69    Kadın           2000  163    65             38.0
# 74         75    Erkek           2001  185    70             42.0
#
#                 Göz              Saç              Doğum_Köy Doğum_İlçe  ...  \
# 3        Kahverengi       Kahverengi              Şirinköyü    Gölcük   ...
# 6        Kahverengi       Kahverengi                 Kartal     Kartal  ...
# 10       Kahverengi           Kumral  Cumhuriyet Mahallesi   Adapazarı  ...
# ...

# %%
#Sütundaki benzersiz değerleri sayma ve sıralama
df['Göz'].value_counts()
# Out:
# Kahverengi         56
# Ela                 6
# Yeşil               4
# Mavi                3
# Koyu Kahverengi     3
# Yeşil               2
# Açık Kahverengi     2
# Siyah               1
# Name: Göz, dtype: int64

# %%
df['Göz'].value_counts(normalize=True)
# Out:
# Kahverengi         0.727273
# Ela                0.077922
# Yeşil              0.051948
# Mavi               0.038961
# Koyu Kahverengi    0.038961
# Yeşil              0.025974
# Açık Kahverengi    0.025974
# Siyah              0.012987
# Name: Göz, dtype: float64

# %%
df['Göz'].value_counts(normalize=True).plot.barh()
# Out:
# <Axes: >

# %%
#Bir sütundaki belirli bir kelimeyi içeren satırları seçme
df[df['Göz'].str.contains('Yeşil')]
# Out:
#     Numaranız Cinsiyet  Doğum_Yılınız  Boy  Kilo  Ayakkabı_Numara     Göz  \
# 4           5    Kadın           2001  157    38             36.0  Yeşil
# 11         12    Kadın           2000  165    75             38.0   Yeşil
# 32         33    Erkek           2000  173    64             39.0   Yeşil
# 37         38    Kadın           2001  160    43             36.0   Yeşil
# 57         58    Kadın           2001  165    62             37.0  Yeşil
# 59         60    Kadın           2002  170    55             39.0   Yeşil
#
#            Saç           Doğum_Köy     Doğum_İlçe  ...  \
# 4        Siyah              Hendek         Hendek  ...
# 11       Siyah           Osmangazi      Osmangazi  ...
# 32  Kahverengi       Gaziosmanpaşa  Gaziosmanpaşa  ...
# 37        Sarı   Çanakça Mahallesi        Çatalca  ...
# 57  Kahverengi          Paşabahçe          Beykoz  ...
# 59      Kumral  Maltepe Mahallesi        Serdivan  ...
#
#              Lise_ İlçe_İl Üniversite_Puan Sıralama  \
# ...

# %%
#Sütundaki verileri histogram grafiği olarak gösterme
df['Not_Ortalama'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Sütundaki verileri yoğunluk grafiği olarak gösterme
df['Kilo'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#Sütundaki verileri kutu grafiği olarak gösterme
df['Not_Ortalama'].plot.box()
# Out:
# <Axes: >
