# %% [markdown]
# <a href="https://colab.research.google.com/github/suacalis/IK-Analitigi-2023/blob/main/A%C3%A7%C4%B1klamal%C4%B1_Matplotlib_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib'e Giriş

# %% [markdown]
# Matplotlib; veri görselleştirmede kullanacağımız temel python kütüphanesidir. 2 ve 3 boyutlu grafikler yapmamızı sağlar.
#
# Matplotlib genelde 2 boyutlu grafik çizimlerinde kullanılırken, seaborn ve plotly express gibi kütüphaneler 3 boyutlu grafik çizimlerinde kullanılır.

# %% [markdown]
# Kütüphanelerin Yüklenmesi

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/suacalis/IK-Analitigi-2023/main/ikanalitikanket.csv',sep=';')

# %% [markdown]
# #Temel Görselleştirme ve Genel Komutlar
#
# Python kütüphaneleri yüklerken çeşitli kalıplaşmış kısaltmalar kullanılır. Pandas için pd, numpy için np gibi.
#
# plt de matplotlib kütüphanesinin kısaltması olarak kullanılır.
#
# #Grafikler çiziminde kullanılan komutlar:
# plt.plot(): Grafiğin ana komutunu oluşturur. Bu komutun içine ilk önce x ekseni, sonrasında y ekseni yazılır. Grafikteki temel bazı değişkenleri değiştirmek istersek ilgili kodu buraya yazmamız gerekir. Örneğin grafiğin rengi, çizgi kalınlığı, aralıklar vs.
#
# figsize:Grafiğin boyutunu belirler. Yaygın olarak
#
# plt.figure(figsize=(8,6))
#
# şeklinde kullanılır. Farklı kullanımları da mevcuttur.
#
# Parantez içindeki ilk yazılan değer grafiğin eni, ikincisi boyudur.
#
# plt.xlabel(): x ekseninin başlığını oluşturur.
#
# plt.ylabel(): y ekseninin başlığını oluşturur.
#
# plt.title(): Grafiğin başlığını oluşturur.
#
# plt.show(): Grafiği çizdirmemizi sağlar. Bu kodu yazmazsak grafik çizilir fakat bazen ekranda gözükmeyebilir.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Numaranız        77 non-null     int64
#  1   Cinsiyet         77 non-null     object
#  2   Doğum_Yılınız    77 non-null     int64
#  3   Boy              77 non-null     int64
#  4   Kilo             77 non-null     int64
#  5   Ayakkabı_Numara  77 non-null     float64
#  6   Göz              77 non-null     object
#  7   Saç              77 non-null     object
#  8   Doğum_Köy        74 non-null     object
#  9   Doğum_İlçe       77 non-null     object
#  10  Doğum_İl         77 non-null     object
#  11  Lise             77 non-null     object
#  12  Lise_ İlçe_İl    77 non-null     object
#  13  Üniversite_Puan  57 non-null     float64
#  14  Sıralama         59 non-null     object
#  15  İl               77 non-null     object
#  16  Baba_Eğitim      76 non-null     object
# ...

# %%
plt.bar(df['Doğum_Yılınız'], df['Kilo'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(df['Doğum_Yılınız'], df['Kilo'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.bar(df['Doğum_Yılınız'], df['Kilo'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.xlabel("Doğum Tarihi")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.bar(df['Doğum_Yılınız'], df['Kilo'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.xlabel("Doğum Tarihi")
plt.ylabel("Kilonuz")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.barh(df['Doğum_Yılınız'], df['Kilo'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.xlabel("Doğum Tarihi")
plt.ylabel("Kilonuz")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.scatter(df['Doğum_Yılınız'],df['Kilo'])
plt.title("Kilo Dağılımı")
plt.xlabel("Kilo")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.scatter(df['Doğum Yılınız'], df['Kilonuz'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.xlabel("Doğum Tarihi")
plt.ylabel("Puan")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.boxplot(df['Kilonuz'],labels=['Kilonuz'])
plt.title("Doğum Tarihine Göre Kilonuz")
plt.xlabel("Doğum Tarihi")
plt.ylabel("Puan")
plt.show()

# %%
plt.boxplot(df['Boyunuz ( cinsinden)'],labels=['Boyunuz ( cinsinden)'])
plt.show()

# %%
plt.boxplot(df['Kilonuz'],patch_artist=True,labels=['Kilonuz'])
plt.show()

# %%
plt.hist(df['Kilonuz'])
plt.show();

# %%
plt.hist(df.Kilonuz)
plt.show();

# %%
plt.hist(df['Boyunuz ( cinsinden)'])
plt.show();
